# %% [markdown]
# # Text Representation

# %% [markdown]
# Text representation in NLP means converting text into a numerical form that a machine learning model can understand and process.

# %% [markdown]
# ## What is Embedding?
#
# Embeddings in NLP is a technique where individual words are represented as real-valued vectors and captures inter-word semantics.
#
#
# In this notebook, We going to intreduce 2 techniques for embedding. These techniques will be used for a machine learning models such as SVM, Random forest, ... ect.

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1jd0u_sGppDKqBYbhtJfGxp14lnUWUTTw" width="900">

# %% [markdown]
# # 1- TF-IDF
#
# <img src="https://drive.google.com/uc?export=view&id=1saSt0mMgOQ2ybbTms1lu_ruhUcBWkKzL" width="500">

# %% [markdown]
# TF-IDF stands for term frequency-inverse document frequency. It is a measure that discounts common words. Used in the fields of information retrieval (IR) and machine learning, that can quantify the importance of words in a document amongst a collection of documents (also known as a corpus).

# %% [markdown]
# ### Components of TF-IDF
#
# 1. **TF (Term Frequency):**
#    Measures how frequently a term appears in a document.
#
#
# $$ \text{TF}(t, d) = \frac{\text{Number of times term } t \text{ appears in document } d}{\text{Total number of terms in document } d} $$
#
#
# 2. **IDF (Inverse Document Frequency):**
#    Measures how important a term is across all documents. Words that appear in many documents get lower scores.
#
# $$    \text{IDF}(t) = \log \left(\frac{\text{Number of all documents N}}{\text{Number of documents containing the term } t}\right) $$

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1JqPILC8TTh3yDQZCSuPNXwm6ER5YeJFh" width="900">

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
doc_1 = "Data is the oil of the digital economy"
doc_2 = "Data is a new oil"

data = [doc_1, doc_2]

# %%
tfidf = TfidfVectorizer()
result = tfidf.fit_transform(data) # returns sparce matrix

# %%
df = pd.DataFrame(result.toarray(), columns=tfidf.get_feature_names_out())
df
# Out:
#        data  digital  economy        is       new       of       oil      the
# 0  0.243777  0.34262  0.34262  0.243777  0.000000  0.34262  0.243777  0.68524
# 1  0.448321  0.00000  0.00000  0.448321  0.630099  0.00000  0.448321  0.00000

# %% [markdown]
# # Cosine similarity
#
# In NLP, Cosine similarity is a metric used to measure how similar the documents are.
#
#
# $$ \text{cosine similarity} = \frac{A \cdot B}{\|A\| \times \|B\|} $$
#
# Where:
# $ A \cdot B $  = dot product of vectors A and B
# $ \|A\| $ = magnitude (length) of vector A
# $ \|B\| $ =  magnitude (length) of vector B
#
# #### Intuition
#
# - If vectors point in the **same direction**, cosine similarity = **1** (maximum similarity).
# - If vectors are **orthogonal (90° apart)**, cosine similarity = **0** (no similarity).
#
# <img src="https://drive.google.com/uc?export=view&id=1b-o8CVfHBsjUGY_hXmxevU91gHidIuxO" width="900">

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Sample text data (replace with your own documents)

doc_1 = "Data is the oil of the digital economy"
doc_2 = "Data is a new oil"

data = [doc_1, doc_2]

# %%
tfidf_vectorizer = TfidfVectorizer() # Create a CountVectorizer instance
vector_matrix = tfidf_vectorizer.fit_transform(data) # Fit and transform the documents into numerical vectors

# %%
# Calculate the cosine similarity between the documents
cosine_similarity_matrix = cosine_similarity(vector_matrix)

df_cosine = pd.DataFrame(data=cosine_similarity_matrix, index=data, columns=data)

df_cosine
# Out:
#                                         Data is the oil of the digital economy  \
# Data is the oil of the digital economy                                1.000000
# Data is a new oil                                                     0.327871
#
#                                         Data is a new oil
# Data is the oil of the digital economy           0.327871
# Data is a new oil                                1.000000

# %% [markdown]
# # 2- What is Word2vec?

# %% [markdown]
# Word2Vec consists of models for generating word embedding. These models are two-layer neural networks having one input layer, one hidden layer, and one output layer.
#
# Word2Vec utilizes two architectures :
# 1. CBOW (Continuous Bag of Words)
# 2. **Skip Gram**
# <img src="https://drive.google.com/uc?export=view&id=1K38nEu_KhgtSJuG2RySwc6U5AAjVAgWZ" width="600">
#
#
# Run this command in terminal to install
# > pip install gensim
#
# We will use fake and real news dataset to do our expirament. You can find the dataset here: https://www.kaggle.com/datasets/clmentbisaillon/fake-and-real-news-dataset?select=True.csv

# %%
# %pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\shaha\downloads\anaconda\lib\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\shaha\downloads\anaconda\lib\site-packages (from gensim) (2.1.3)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\shaha\downloads\anaconda\lib\site-packages (from gensim) (1.15.3)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\shaha\downloads\anaconda\lib\site-packages (from gensim) (8.0.1)
# Requirement already satisfied: wrapt in c:\users\shaha\downloads\anaconda\lib\site-packages (from smart_open>=1.8.1->gensim) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import nltk
import numpy as np
import re
import gensim

from nltk.tokenize import word_tokenize

# %%
# !pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-1.0.2-py3-none-any.whl.metadata (40 kB)
# Collecting kagglesdk<1.0,>=0.1.22 (from kagglehub)
#   Downloading kagglesdk-0.1.37-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in c:\users\shaha\downloads\anaconda\lib\site-packages (from kagglehub) (24.2)
# Requirement already satisfied: pyyaml in c:\users\shaha\downloads\anaconda\lib\site-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in c:\users\shaha\downloads\anaconda\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\shaha\downloads\anaconda\lib\site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: protobuf in c:\users\shaha\downloads\anaconda\lib\site-packages (from kagglesdk<1.0,>=0.1.22->kagglehub) (5.29.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shaha\downloads\anaconda\lib\site-packages (from requests->kagglehub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shaha\downloads\anaconda\lib\site-packages (from requests->kagglehub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shaha\downloads\anaconda\lib\site-packages (from requests->kagglehub) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shaha\downloads\anaconda\lib\site-packages (from requests->kagglehub) (2025.4.26)
# Requirement already satisfied: colorama in c:\users\shaha\downloads\anaconda\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-1.0.2-py3-none-any.whl (70 kB)
# Downloading kagglesdk-0.1.37-py3-none-any.whl (262 kB)
# Installing collected packages: kagglesdk, kagglehub
#
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    ---------------------------------------- 0/2 [kagglesdk]
#    -------------------- ------------------- 1/2 [kagglehub]
#    -------------------- ------------------- 1/2 [kagglehub]
#    -------------------- ------------------- 1/2 [kagglehub]
#    -------------------- ------------------- 1/2 [kagglehub]
#    -------------------- ------------------- 1/2 [kagglehub]
#    -------------------- ------------------- 1/2 [kagglehub]
#    -------------------- ------------------- 1/2 [kagglehub]
#    -------------------- ------------------- 1/2 [kagglehub]
#    -------------------- ------------------- 1/2 [kagglehub]
#    ---------------------------------------- 2/2 [kagglehub]
#
# Successfully installed kagglehub-1.0.2 kagglesdk-0.1.37

# %%
import kagglehub
import pandas as pd
import os

# Download latest version
path = kagglehub.dataset_download(
    "clmentbisaillon/fake-and-real-news-dataset")

print("Path to dataset files:", path)

# Read True.csv
file_path = os.path.join(path, "True.csv")

df = pd.read_csv(
    file_path, engine="python", on_bad_lines="skip")

df.head()
# Out:
# Downloading to C:\Users\shaha\.cache\kagglehub\datasets\clmentbisaillon\fake-and-real-news-dataset\1.archive...
# 100%|██████████| 41.0M/41.0M [00:09<00:00, 4.50MB/s]
# Extracting files...
# Path to dataset files: C:\Users\shaha\.cache\kagglehub\datasets\clmentbisaillon\fake-and-real-news-dataset\versions\1
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
df['text'] = df['text'].fillna('').astype(str)

tokens = []

for i in df['text']:
    token = word_tokenize(i)
    tokens.append(token)

# %%
w2v = gensim.models.Word2Vec(tokens, min_count=1, vector_size=100, window=5, sg=1)
print(len(w2v.wv.key_to_index))
# Out:
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# 100446

# %%
print("Cosine similarity between 'provide' and 'program' - Skip Gram : ",w2v.wv.similarity('provide', 'program'))
# Out:
# Cosine similarity between 'provide' and 'program' - Skip Gram :  0.43025565

# %%
print("words that similar to 'program' - Skip Gram : ",w2v.wv.most_similar('program'))
# Out:
# words that similar to 'program' - Skip Gram :  [('programme', 0.806389570236206), ('programs', 0.7908989191055298), ('arsenal', 0.6988049149513245), ('modernization', 0.6900235414505005), ('bond-buying', 0.6861550807952881), ('programmes', 0.6794198155403137), ('voucher', 0.6767875552177429), ('EB-5', 0.6759913563728333), ('restraints', 0.6746720671653748), ('AGM-86B', 0.6686280369758606)]

# %% [markdown]
# # Tasks

# %% [markdown]
# ### Task 1: Cosine Similarity
# Use the Cosine Similarity method to determine how similar the following sentences are.
#
# 'This is the first document.',
# 'This document is the second document.',
# 'And this is the third one.',
# 'Is this the first document?'

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

documents = ['This is the first document.', 'This document is the second document.',
             'And this is the third one.', 'Is this the first document?']

tfidf_vectorizer = TfidfVectorizer()
vector_matrix = tfidf_vectorizer.fit_transform(documents)

cosine_similarity_matrix = cosine_similarity(vector_matrix)

task1_result = pd.DataFrame(cosine_similarity_matrix, index=['Document 1', 'Document 2', 'Document 3', 'Document 4'], 
                            columns=['Document 1', 'Document 2', 'Document 3', 'Document 4'])

task1_result
# Out:
#             Document 1  Document 2  Document 3  Document 4
# Document 1    1.000000    0.646926    0.307772    1.000000
# Document 2    0.646926    1.000000    0.225240    0.646926
# Document 3    0.307772    0.225240    1.000000    0.307772
# Document 4    1.000000    0.646926    0.307772    1.000000

# %% [markdown]
# ### Task 2: TF-IDF
# Use tf-idf method on the sentences below to determine the important words.
#
# 'data science is one of the most important fields of science',
# 'this is one of the best data science courses',
# 'data scientists analyze data'

# %%
sentences = [ 'data science is one of the most important fields of science', 'this is one of the best data science courses',
    'data scientists analyze data']

tfidf = TfidfVectorizer()
result = tfidf.fit_transform(sentences)

task2_result = pd.DataFrame( result.toarray(), columns=tfidf.get_feature_names_out(), index=['Sentence 1', 'Sentence 2', 'Sentence 3'])

display(task2_result)

print("Most important word(s) in each sentence:")
for sentence, row in task2_result.iterrows():
    max_score = row.max()
    important_words = row[row == max_score].index.tolist()
    print(sentence, ":", important_words, "->", round(max_score, 4))
# Out:
#              analyze      best   courses      data    fields  important  \
# Sentence 1  0.000000  0.000000  0.000000  0.189526  0.320895   0.320895
# Sentence 2  0.000000  0.400294  0.400294  0.236420  0.000000   0.000000
# Sentence 3  0.542701  0.000000  0.000000  0.641055  0.000000   0.000000
#
#                   is      most        of       one   science  scientists  \
# Sentence 1  0.244049  0.320895  0.488098  0.244049  0.488098    0.000000
# Sentence 2  0.304434  0.000000  0.304434  0.304434  0.304434    0.000000
# Sentence 3  0.000000  0.000000  0.000000  0.000000  0.000000    0.542701
#
#                  the      this
# Sentence 1  0.244049  0.000000
# Sentence 2  0.304434  0.400294
# Sentence 3  0.000000  0.000000
# Most important word(s) in each sentence:
# Sentence 1 : ['of', 'science'] -> 0.4881
# Sentence 2 : ['best', 'courses', 'this'] -> 0.4003
# Sentence 3 : ['data'] -> 0.6411

# %% [markdown]
# ## Word2vec

# %% [markdown]
# ### Task 3:
#
# Download the Simpsons dataset **(simpsons_script_lines.csv)** and apply the preprocessing procedure.
# Use the **'spoken_words'** column.
# ```
# def clean_text(text):
#     text = text.lower()
#     text = re.sub(r"[0-9]", '', text)
#     text = re.sub(r"[)(,”“.’$-]", '', text)
#     return text
# ```
# Create a skip gram Word2Vec model as below.
# ```
# Skip_gram_model = gensim.models.Word2Vec(tokens, min_count = 1, vector_size = 100, window = 5, sg = 1)

# %%
import pandas as pd
import re
import gensim
from nltk.tokenize import word_tokenize

# Load the Simpsons dataset.
df_simpsons = pd.read_csv('simpsons_script_lines.csv')

def clean_text(text):
    text = text.lower()
    text = re.sub(r"[0-9]", '', text)
    text = re.sub(r"[)(,”“.’$-]", '', text)
    return text

# spoken_words contains missing values, so remove them before tokenization.
cleaned_text = df_simpsons['spoken_words'].dropna().apply(clean_text)

tokens = []
for text in cleaned_text:
    if text.strip():
        # preserve_line=True avoids requiring the Punkt sentence tokenizer.
        tokens.append(word_tokenize(text, preserve_line=True))

Skip_gram_model = gensim.models.Word2Vec( tokens, min_count=1, vector_size=100, window=5, sg=1)

print("Number of tokenized lines:", len(tokens))
print("Vocabulary size:", len(Skip_gram_model.wv))
# Out:
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'
# Number of tokenized lines: 131839
# Vocabulary size: 44282

# %% [markdown]
# ### Task 4
#
# Use: wv.most_similar() method to :
#
# 1.	Find the words similar to “homer”.
#
# 2.	Find the words similar to “marge”.
#
# 3. Find the words similar to “bart”

# %%
print("Words similar to 'homer':")
print(Skip_gram_model.wv.most_similar('homer'))

print("\nWords similar to 'marge':")
print(Skip_gram_model.wv.most_similar('marge'))

print("\nWords similar to 'bart':")
print(Skip_gram_model.wv.most_similar('bart'))
# Out:
# Words similar to 'homer':
# [('abe', 0.8682540059089661), ('marge', 0.8477839827537537), ('grampa', 0.8351320624351501), ('superstar', 0.833764374256134), ('sweetheart', 0.8325980305671692), ('eliza', 0.8232806921005249), ('bart', 0.8180186748504639), ('barney', 0.8172738552093506), ('jessica', 0.8156225085258484), ('jay', 0.813603937625885)]
#
# Words similar to 'marge':
# [('homer', 0.8477840423583984), ('abe', 0.8363658785820007), ('sweetheart', 0.8347689509391785), ('sweetie', 0.8286363482475281), ('lisa', 0.8254822492599487), ('honey', 0.8175966143608093), ('midge', 0.8130221366882324), ('homie', 0.8120588064193726), ('youse', 0.8094320893287659), ('allison', 0.8083942532539368)]
#
# Words similar to 'bart':
# [('lisa', 0.8772004842758179), ('milhouse', 0.8749616146087646), ('laddie', 0.8345078229904175), ('jessica', 0.8340935111045837), ('sweetheart', 0.8233357071876526), ('allison', 0.8200559616088867), ('sweetie', 0.8192795515060425), ('luann', 0.8186768889427185), ('homer', 0.8180187344551086), ('maggie', 0.8168731927871704)]

# %% [markdown]
# ### Task 5
#
# Use the wv.doesnt_match() method to :
#
# 1.	Find which of 'jimbo', 'milhouse’, and 'kearney’ does not belong to the list.
#
# 3.	Find the odd one among "nelson", "bart", and "milhouse".
#
# 4.	Find the odd one among ‘homer', 'patty', and ‘selma'.
#
# *Hint: You need to pass the strings as List*

# %%
print( "Odd word among jimbo, milhouse, kearney:", Skip_gram_model.wv.doesnt_match(['jimbo', 'milhouse', 'kearney']))

print("Odd word among nelson, bart, milhouse:", Skip_gram_model.wv.doesnt_match(['nelson', 'bart', 'milhouse']))

print( "Odd word among homer, patty, selma:", Skip_gram_model.wv.doesnt_match(['homer', 'patty', 'selma']))
# Out:
# Odd word among jimbo, milhouse, kearney: milhouse
# Odd word among nelson, bart, milhouse: nelson
# Odd word among homer, patty, selma: homer
